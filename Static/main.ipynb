# %%
# Import dependencies
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine

# %%
# July File
july_csv= pd.read_csv("../Resources/JC-202407-citibike-tripdata.csv")

august_csv= pd.read_csv("../Resources/JC-202408-citibike-tripdata.csv")

september_csv= pd.read_csv("../Resources/JC-202409-citibike-tripdata.csv")

# %%
# Concatenate the dfs vertically
combined_df = pd.concat([july_csv, august_csv, september_csv], ignore_index=True)

# Display new df
combined_df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  6B61E4880B1DE1E9  electric_bike  2024-07-31 12:06:49.628
# 1  B593705A700E04B9  electric_bike  2024-07-01 07:53:20.019
# 2  19CFBBAF90BF45B8  electric_bike  2024-07-30 14:57:29.219
# 3  8E6563C41AA8A1B4  electric_bike  2024-07-17 17:02:20.147
# 4  44065C7E4AE573FA  electric_bike  2024-07-20 17:19:44.970
#
#                   ended_at                       start_station_name  \
# 0  2024-07-31 12:23:59.876        14 St Ferry - 14 St & Shipyard Ln
# 1  2024-07-01 08:13:56.570                      Leonard Gordon Park
# 2  2024-07-30 15:10:49.553                       Liberty Light Rail
# 3  2024-07-17 17:04:50.818                         Grand St & 14 St
# 4  2024-07-20 17:39:09.894  Hoboken Terminal - River St & Hudson Pl
#
#   start_station_id            end_station_name end_station_id  start_lat  \
# 0            HB202             Brunswick & 6th          JC081  40.752961
# ...

# %%
combined_df.isnull().sum()
print(combined_df)
# Out:
#                  ride_id  rideable_type               started_at  \
# 0       6B61E4880B1DE1E9  electric_bike  2024-07-31 12:06:49.628
# 1       B593705A700E04B9  electric_bike  2024-07-01 07:53:20.019
# 2       19CFBBAF90BF45B8  electric_bike  2024-07-30 14:57:29.219
# 3       8E6563C41AA8A1B4  electric_bike  2024-07-17 17:02:20.147
# 4       44065C7E4AE573FA  electric_bike  2024-07-20 17:19:44.970
# ...                  ...            ...                      ...
# 334447  9741E4C735EFCC0D  electric_bike  2024-09-06 23:14:41.429
# 334448  0575344ACB345B3E  electric_bike  2024-09-19 07:59:28.938
# 334449  A1F4AC58D9DACD40   classic_bike  2024-09-18 06:41:58.514
# 334450  190F180F7028F3A3  electric_bike  2024-09-09 18:54:52.459
# 334451  7D8F76A993B7241F  electric_bike  2024-09-24 15:18:09.145
#
#                        ended_at                       start_station_name  \
# 0       2024-07-31 12:23:59.876        14 St Ferry - 14 St & Shipyard Ln
# ...
